# %% [markdown]
# <a href="https://colab.research.google.com/github/mandalsantanu16092002/mnist-ml-classification/blob/main/decision_tree_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/<mandalsantanu16092002>/mnist-ml-classification.git
# Out:
# /bin/bash: line 1: mandalsantanu16092002: No such file or directory

# %%
import pandas as pd
import numpy as np

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
train_df = pd.read_csv('/kaggle/input/mnist_train.csv')
test_df  = pd.read_csv('/kaggle/input/mnist_test.csv')

print(train_df.shape)
print(test_df.shape)
# Out:
# (60000, 785)
# (10000, 785)

# %%
X_train = train_df.drop('label', axis=1).values
y_train = train_df['label'].values

X_test = test_df.drop('label', axis=1).values
y_test = test_df['label'].values

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

svm = SVC(kernel='rbf', gamma='scale')
svm.fit(X_train, y_train)

# %%
y_pred = svm.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("Test Accuracy:", accuracy)
